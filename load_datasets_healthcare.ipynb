# %% [markdown]
# ### This notebook performs post-processing of ClinicBench data to generate the evaluation dataset
#
# #### To setup:
#
# - git clone the tutorial repo
# - To clone the healthcare submodule:
#     - git submodule init
#     - git submodule update

# %%
import pandas as pd
import random
import jsonlines

# %% [markdown]
# ### Load the healthcare data that include symptom, disease, commonMedications

# %%
path_to_csv = "datasets/healthcare/Treatment-Recommendation.csv"
df = pd.read_csv(path_to_csv)
df
# Out:
#      idx                           disease  \
# 0      0                    Panic disorder
# 1      1                  Vocal cord polyp
# 2      2                   Turner syndrome
# 3      3                    Cryptorchidism
# 4      4  Poisoning due to ethylene glycol
# ..   ...                               ...
# 791  791                    Kaposi sarcoma
# 792  792                 Spondylolisthesis
# 793  793               Pseudotumor cerebri
# 794  794       Conjunctivitis due to virus
# 795  795            Open wound of the nose
#
#                                                Symptom  \
# 0    ['Anxiety and nervousness', 'Depression', 'Sho...
# 1    ['Hoarse voice', 'Sore throat', 'Difficulty sp...
# 2    ['Groin mass', 'Leg pain', 'Hip pain', 'Suprap...
# 3    ['Symptoms of the scrotum and testes', 'Swelli...
# 4    ['Abusing alcohol', 'Fainting', 'Hostile behav...
# ..                                                 ...
# 791  ['Leg pain', 'Foot or toe pain', 'Cough', 'Lip...
# 792  ['Low back pain', 'Back pain', 'Leg pain', 'Hi...
# 793  ['Headache', 'Diminished vision', 'Dizziness',...
# 794  ['Eye redness', 'Pain in eye', 'Itchiness of e...
# 795  ['Headache', 'Nosebleed', 'Facial pain', 'Hot ...
#
#                                                 reason  \
# 0    Panic disorder is an anxiety disorder characte...
# 1                       beclomethasone nasal product,
# 2    Turner syndrome or Ullrich\xe2\x80\x93Turner s...
# 3    Cryptorchidism (derived from the Greek \xce\xb...
# 4                                           thiamine,
# ..                                                 ...
# 791  Kaposi sarcoma (KS) is a tumor caused by Human...
# 792  Spondylolisthesis is the anterior or posterior...
# 793  Idiopathic intracranial hypertension (IIH), so...
# 794  Conjunctivitis (also called pink eye or madras...
# 795                  tetanus toxoid vaccine (adacel),
#
#                                     TestsAndProcedures  \
# 0    ['Psychotherapy', 'Mental health counseling', ...
# 1    ['Tracheoscopy and laryngoscopy with biopsy', ...
# 2    ['Complete physical skin exam performed (ML)',...
# 3    ['Complete physical skin exam performed (ML)',...
# 4    ['Intravenous fluid replacement', 'Hematologic...
# ..                                                 ...
# 791  ['Glucose measurement (Glucose level)', 'Compl...
# 792  ['Radiographic imaging procedure', 'Plain x-ra...
# 793  ['Intravenous fluid replacement', 'Magnetic re...
# 794  ['Ophthalmic examination and evaluation (Eye e...
# 795  ['Suturing of wound', 'Wound care management',...
#
#                                      commonMedications
# 0    ['Lorazepam', 'Alprazolam (Xanax)', 'Clonazepa...
# 1    ['Esomeprazole (Nexium)', 'Beclomethasone Nasa...
# 2    ['Somatropin', 'Sulfamethoxazole (Bactrim)', '...
# 3    ['Haemophilus B Conjugate Vaccine (Obsolete)',...
# 4    ['Lorazepam', 'Thiamine', 'Naloxone (Suboxone)...
# ..                                                 ...
# 791  ['Ritonavir (Norvir)', 'Lopinavir', 'Tenofovir...
# 792  ['Diclofenac', 'Piroxicam', 'Cortisone', 'Levo...
# 793  ['Acetazolamide (Diamox)', 'Topiramate (Topama...
# 794  ['Erythromycin', 'Gentamicin Ophthalmic', 'Sod...
# 795  ['Lidocaine', 'Tetanus Toxoid Vaccine (Adacel)...
#
# [796 rows x 6 columns]

# %% [markdown]
# ### Function to generate question associated with each sample, over all scenarios
#
# - To generate more realistic questions in Scenarios 1, 2, 3, we randomly sample a few symptoms from all of the available symptoms.

# %%
def add_question_column(df, scenario="scenario_1"):
    def form_question_scenario_1(symptoms, nsamples=8):
        # SingleStep
        return "I have " + ", ".join(random.sample(eval(symptoms), nsamples)) + " symptoms. What disease do I have?"
        
    def form_question_scenario_2(symptoms, nsamples=8):
        # MultiStep
        return "I have " + ", ".join(random.sample(eval(symptoms), nsamples)) + " symptoms. What are the recommended medications?"
        
    def add_expected_tools_column(df):
        # Expected tools used
        df["expected_tools_scenario_2"] = ["find_disease find_common_medications"] * len(df)
        return df
        
    def form_question_scenario_3(symptoms, nsamples=8):
        # Same questions over samples in dataset
        return "I have " + ", ".join(random.sample(eval(symptoms), nsamples)) + " symptoms. What disease do I have?"
        
    def form_question_scenario_4():
        # No symptoms
        return "I feel great and don't have medical symptoms. Do I have any disease or need medications?"

    column = "question_" + scenario
    
    df[column] = df["Symptom"]
    
    if scenario == "scenario_1":
        df[column] = df[column].apply(lambda x: form_question_scenario_1(x))
    elif scenario == "scenario_2":
        df[column] = df[column].apply(lambda x: form_question_scenario_2(x))
        df = add_expected_tools_column(df)
    elif scenario == "scenario_3":
        df[column] = [form_question_scenario_3(df["Symptom"].iloc[0])] * len(df)
    elif scenario == "scenario_4":
        df[column] = [form_question_scenario_4()] * len(df)
    else:
        raise

    return df

# %% [markdown]
# ### Prepare data (csv) to be used by our tools. A tool will retrieve data from this csv
#
# - Save first n rows of data to csv.

# %%
nrows = 3
first_nrows = df.head(nrows)
first_nrows.to_csv('datasets/healthcare_postprocessed/Treatment-Recommendation-First-' + str(nrows) + '-Rows.csv', index=False)

# %% [markdown]
# ### Prepare evaluation data (jsonl) to be used by InsepctAI for evaluating agent
#
# - Save first n rows of data to jsonl.

# %%
path_to_jsonl = 'datasets/healthcare_postprocessed/Treatment-Recommendation-First-' + str(nrows) + '-Rows.jsonl'

first_nrows = df.head(nrows)
first_nrows = add_question_column(first_nrows, scenario="scenario_1")
first_nrows = add_question_column(first_nrows, scenario="scenario_2")
first_nrows = add_question_column(first_nrows, scenario="scenario_3")
first_nrows = add_question_column(first_nrows, scenario="scenario_4")

list_of_dicts = first_nrows.to_dict(orient='records')
for d in list_of_dicts:
    for k, v in d.items():
        if type(v) == str and v[0] == "[" and type(eval(v)) == list:
            d[k] = eval(v)

with jsonlines.open(path_to_jsonl, 'w') as w:
    w.write_all(list_of_dicts)
# Out:
# /var/folders/tn/3sjy3nsd2qg721pjs8ywpy1r0000gn/T/ipykernel_79729/2384123864.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df["Symptom"]
# /var/folders/tn/3sjy3nsd2qg721pjs8ywpy1r0000gn/T/ipykernel_79729/2384123864.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: form_question_scenario_1(x))
# /var/folders/tn/3sjy3nsd2qg721pjs8ywpy1r0000gn/T/ipykernel_79729/2384123864.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df["Symptom"]
# /var/folders/tn/3sjy3nsd2qg721pjs8ywpy1r0000gn/T/ipykernel_79729/2384123864.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: form_question_scenario_2(x))
# /var/folders/tn/3sjy3nsd2qg721pjs8ywpy1r0000gn/T/ipykernel_79729/2384123864.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["expected_tools_scenario_2"] = ["find_disease find_common_medications"] * len(df)
# /var/folders/tn/3sjy3nsd2qg721pjs8ywpy1r0000gn/T/ipykernel_79729/2384123864.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df["Symptom"]
# /var/folders/tn/3sjy3nsd2qg721pjs8ywpy1r0000gn/T/ipykernel_79729/2384123864.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = [form_question_scenario_3(df["Symptom"].iloc[0])] * len(df)
# /var/folders/tn/3sjy3nsd2qg721pjs8ywpy1r0000gn/T/ipykernel_79729/2384123864.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df["Symptom"]
# /var/folders/tn/3sjy3nsd2qg721pjs8ywpy1r0000gn/T/ipykernel_79729/2384123864.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = [form_question_scenario_4()] * len(df)
